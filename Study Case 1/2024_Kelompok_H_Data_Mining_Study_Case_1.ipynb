# %% [markdown]
# <a href="https://colab.research.google.com/github/mabdulghofur142/Data-Mining/blob/main/Study%20Case%201/2024_Kelompok_H_Data_Mining_Study_Case_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **NIM - Nama**
#
# 11220940000004 - Rio Tri Wibowo
#
# 11220940000008 - Margita Zahra Ramandanisya
#
# 11220940000010 - Siti Magfiroh
#
# 11220940000020 - Muhammad Abdul Ghofur
#
# 11220940000041 - Muhammad Akhdan A'qil

# %% [markdown]
# ## Tugas Data Mining Study Case 1

# %% [markdown]
# **Kasus:**
#
# - Anda adalah seorang Data Analyst yang bekerja di PT Ray Pink Property Indonesia (RPPI).
# - RPPI adalah perusahaan property yang berdiri sejak 11 tahun yang lalu.
# - RPPI memliki kantor cabang di 7 propinsi di Indonesia dan jumlahnya terus bertambah.
# - Valuasi RPPI tahun ini mencapai Rp 7 Trilyun, meningkat 7% dari tahun sebelumnya.
# - Bidang usaha RPPI adalah investasi dan jual-beli property secara umum, termasuk bekerja sama dengan developer perumahan.
# - Data Engineer (DE)/Database Administrator (DBA) RPPI berhasil mengumpulkan data rumah-rumah yang dijual di beberapa kota di Indonesia.
# - Sebagai Data Analyst anda akan hadir dan melakukan presentasi pada rapat direksi untuk memberikan insight dari data ke upper management (C-Level, senior managers, dan komisaris perusahaan).
# - Di studi kasus ini anda mempersiapkan "bahan presentasi" dengan cara melakukan EDA pada data yang diterima dari DE/DBA.
#
#
# **Petunjuk:**
#
# Di studi kasus pertama, anda mendapat bantuan keterangan dari manajemen. Setelah berdiskusi over lunch dengan beberapa manager senior, anda mendengar bahwa mereka ingin mengetahui:
#
# 1. Kualitas data yang dimiliki perusahaan.
# 2. Apakah ada saran perbaikan data ke DE/DBA perusahaan agar RPPI menjadi data driven company yang unggul.
# 3. Dari data yang ada, apakah ada kecenderungan rumah disuatu kota lebih mahal/murah dibandingkan kota lain?
# 4. Dari data yang ada, apakah bisa dibuat rekomendasi sebaiknya RPPI membuat kantor cabang berikutnya di kota mana? Mengapa? (Asumsikan RPPI belum memiliki cabang di kota-kota yang disebutkan di data).
# 5. Rumah dengan karakteristik seperti apa yang paling banyak dijual?
# 6. Jika RPPI ingin melakukan investasi (max) Rp. 25 Milyar minggu besok, apakah dari data anda dapat memberikan rekomendasi rumah mana saja yang akan berpotensi menghasilkan keuntungan bagi perusahaan?
# 7. Dan yang terpenting, informasi berharga apa lagi yang bisa anda dapatkan dari data?
#
# **Catatan:**
#
# - Anda diperbolehkan melakukan augmentasi data (menambah data eksternal).
# - Yakinkan menuliskan asumsi anda atas kesimpulan dan rekomendasi yang diberikan ke perusahaan.
# - Yakinkan kesimpulan dan rekomendasi ditujukan ke perusahaan (bukan dosen mata kuliah).
# - Anda boleh menggunakan software visualisasi apapun, misal excel, Ms Word, Photoshop, dsb.
# - Yakinkan file images dapat dibuka (nampak) saat ipynb di Jupyter notebook anda dibuka di Google Colab.
# Tips: hati-hati dalam melakukan penamaan file, Google colab case sensitive.
# - Interpretasi diberikan menggunakan cell markdown tepat dibawah output code yang relevan diatasnya.
# - Anda tidak diperkenankan bertanya pertanyaan yang:
# -- Merupakan jawaban atau menjurus ke jawaban studi kasus.
# -- Debugging - code error (anda diharapkan melakukan code troubleshooting sendiri via mesin pencari)
# - Pada studi kasus ini anda hanya diperkenankan untuk melakukan EDA (bukan modeling seperti prediksi/forecasting)
# Komponen Penilaian:
# Code tidak diubah sejak deadline studi kasus.
# Code dapat di "Run-All" di Google Colab oleh dosen tanpa error.
# Pemilihan preprocessing dan visualisasi yang tepat
# Interpretasi dan rekomendasi dengan narasi dan kualitas yang baik, serta berdasarkan atas (pengolahan) data.
# Kreativitas dan inovasi pengolahan data dan penyajian visualisasi.
#
# **Data Understanding (DU):**
#
# Keterangan Varabel:
#
# - Created_at: Tanggal dimana iklan rumah dibuat
# - LT : Luas Tanah properti yang ditawarkan
# - LB : Luas Bangunan properti yang ditawarkan
# - KT : Jumlah Kamar Tidur properti yang ditawarkan
# - KM : Jumlah Kamar Mandi properti yang ditawarkan
# - Garasi : Jumlah Kapasitas Garasi di properti yang ditawarkan
# - Carport : Kapasitas Carport di properti yang ditawarkan
# - Lokasi : Detail lokasi properti yang ditawarkan
# - Sertifikat: Jenis sertifikat properti yang ditawarkan
# - Listrik : Daya listrik dari properti yang ditawarkan
# - Hadap : Keterangan property yang ditawarkan menghadap ke arah mana
# - Harga : Harga property yang ditawarkan dalam Rupiah
# - URL : Alamat tautan (link) property yang ditawarkan.
# - Deskripsi : Deskripsi iklan property yang ditawarkan.

# %% [markdown]
# ## Pengolahan Data

# %%
import pandas as pd, matplotlib.pyplot as plt, seaborn as sns, numpy as np
# !mkdir data
# !wget -P data/ https://raw.githubusercontent.com/taudataanalytics/Data-Mining--Penambangan-Data--Ganjil-2024/master/data/jakarta.csv
# !wget -P data/ https://raw.githubusercontent.com/taudataanalytics/Data-Mining--Penambangan-Data--Ganjil-2024/master/data/depok.csv
# !wget -P data/ https://raw.githubusercontent.com/taudataanalytics/Data-Mining--Penambangan-Data--Ganjil-2024/master/data/bogor.csv
# !wget -P data/ https://raw.githubusercontent.com/taudataanalytics/Data-Mining--Penambangan-Data--Ganjil-2024/master/data/tangerang.csv
# !wget -P data/ https://raw.githubusercontent.com/taudataanalytics/Data-Mining--Penambangan-Data--Ganjil-2024/master/data/bekasi.csv
dfJakarta = pd.read_csv("data/jakarta.csv")
dfDepok = pd.read_csv("data/depok.csv")
dfBogor = pd.read_csv("data/bogor.csv")
dfTangerang = pd.read_csv("data/tangerang.csv")
dfBekasi = pd.read_csv("data/bekasi.csv")
# Out:
# mkdir: cannot create directory ‘data’: File exists
# --2024-09-25 17:25:56--  https://raw.githubusercontent.com/taudataanalytics/Data-Mining--Penambangan-Data--Ganjil-2024/master/data/jakarta.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 63832 (62K) [text/plain]
# Saving to: ‘data/jakarta.csv.4’
#
# jakarta.csv.4       100%[===================>]  62.34K  --.-KB/s    in 0.01s
#
# 2024-09-25 17:25:56 (4.44 MB/s) - ‘data/jakarta.csv.4’ saved [63832/63832]
#
# --2024-09-25 17:25:56--  https://raw.githubusercontent.com/taudataanalytics/Data-Mining--Penambangan-Data--Ganjil-2024/master/data/depok.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 43191 (42K) [text/plain]
# Saving to: ‘data/depok.csv.4’
#
# depok.csv.4         100%[===================>]  42.18K  --.-KB/s    in 0.008s
#
# 2024-09-25 17:25:57 (4.99 MB/s) - ‘data/depok.csv.4’ saved [43191/43191]
#
# --2024-09-25 17:25:57--  https://raw.githubusercontent.com/taudataanalytics/Data-Mining--Penambangan-Data--Ganjil-2024/master/data/bogor.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 68006 (66K) [text/plain]
# Saving to: ‘data/bogor.csv.4’
#
# bogor.csv.4         100%[===================>]  66.41K  --.-KB/s    in 0.02s
#
# 2024-09-25 17:25:57 (3.85 MB/s) - ‘data/bogor.csv.4’ saved [68006/68006]
#
# --2024-09-25 17:25:57--  https://raw.githubusercontent.com/taudataanalytics/Data-Mining--Penambangan-Data--Ganjil-2024/master/data/tangerang.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 46485 (45K) [text/plain]
# Saving to: ‘data/tangerang.csv.4’
#
# tangerang.csv.4     100%[===================>]  45.40K  --.-KB/s    in 0.009s
#
# 2024-09-25 17:25:57 (5.03 MB/s) - ‘data/tangerang.csv.4’ saved [46485/46485]
#
# --2024-09-25 17:25:57--  https://raw.githubusercontent.com/taudataanalytics/Data-Mining--Penambangan-Data--Ganjil-2024/master/data/bekasi.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 71038 (69K) [text/plain]
# Saving to: ‘data/bekasi.csv.4’
#
# bekasi.csv.4        100%[===================>]  69.37K  --.-KB/s    in 0.01s
#
# 2024-09-25 17:25:58 (4.90 MB/s) - ‘data/bekasi.csv.4’ saved [71038/71038]

# %%
dfJakarta.head().T
# Out:
#                                                              0  \
# created_at                                          06-12-2021
# LT                                                       202.0
# LB                                                       198.0
# KT                                                         8.0
# KM                                                         3.0
# garasi                                                     NaN
# carport                                                    NaN
# lokasi                                           Jakarta Pusat
# sertifikat                                                 SHM
# listrik                                                 2200.0
# hadap                                                      NaN
# harga                                             4500000000.0
# URL          https://www.rumah.com/listing-properti/dijual-...
# deskripsi    Dekat Cikini Salemba Taman Isamail Marzuki Kam...
# Unnamed: 14                                                NaN
# Unnamed: 15                                                NaN
# Unnamed: 16                                                NaN
# Unnamed: 17                                                NaN
# Unnamed: 18                                                NaN
# Unnamed: 19                                                NaN
# Unnamed: 20                                                NaN
# Unnamed: 21                                                NaN
# Unnamed: 22                                                NaN
# Unnamed: 23                                                NaN
# Unnamed: 24                                                NaN
# Unnamed: 25                                                NaN
#
#                                                              1  \
# created_at                                          02-12-2021
# LT                                                        30.0
# LB                                                        55.0
# KT                                                         2.0
# KM                                                         1.0
# garasi                                                     NaN
# carport                                                    1.0
# lokasi                                           Jakarta Pusat
# sertifikat                                                 SHM
# listrik                                                 2200.0
# hadap                                                      NaN
# harga                                             1100000000.0
# URL          https://www.rumah.com/listing-properti/dijual-...
# deskripsi    Mengusung konsep minimalis, dan didukung denga...
# Unnamed: 14                                                NaN
# Unnamed: 15                                                NaN
# Unnamed: 16                                                NaN
# Unnamed: 17                                                NaN
# Unnamed: 18                                                NaN
# Unnamed: 19                                                NaN
# Unnamed: 20                                                NaN
# Unnamed: 21                                                NaN
# Unnamed: 22                                                NaN
# Unnamed: 23                                                NaN
# Unnamed: 24                                                NaN
# Unnamed: 25                                                NaN
#
#                                                              2  \
# created_at                                          06-12-2021
# LT                                                        19.0
# LB                                                        35.0
# KT                                                         2.0
# KM                                                         1.0
# garasi                                                     NaN
# carport                                                    NaN
# lokasi                                           Jakarta Pusat
# sertifikat                                                 SHM
# listrik                                                 2200.0
# hadap                                                      NaN
# harga                                              395000000.0
# URL          https://www.rumah.com/listing-properti/dijual-...
# deskripsi    Dekat dengan Mall Atrium Senen, dekat dengan a...
# Unnamed: 14                                                NaN
# Unnamed: 15                                                NaN
# Unnamed: 16                                                NaN
# Unnamed: 17                                                NaN
# Unnamed: 18                                                NaN
# Unnamed: 19                                                NaN
# Unnamed: 20                                                NaN
# Unnamed: 21                                                NaN
# Unnamed: 22                                                NaN
# Unnamed: 23                                                NaN
# Unnamed: 24                                                NaN
# Unnamed: 25                                                NaN
#
#                                                              3  \
# created_at                                          06-12-2021
# LT                                                        33.0
# LB                                                        42.0
# KT                                                         2.0
# KM                                                         2.0
# garasi                                                     NaN
# carport                                                    1.0
# lokasi                                           Jakarta Pusat
# sertifikat                                                 SHM
# listrik                                                 2200.0
# hadap                                                      NaN
# harga                                              835000000.0
# URL          https://www.rumah.com/listing-properti/dijual-...
# deskripsi    Berlokasi sangat strategis, sangat dekat ke Tu...
# Unnamed: 14                                                NaN
# Unnamed: 15                                                NaN
# Unnamed: 16                                                NaN
# Unnamed: 17                                                NaN
# Unnamed: 18                                                NaN
# Unnamed: 19                                                NaN
# Unnamed: 20                                                NaN
# Unnamed: 21                                                NaN
# Unnamed: 22                                                NaN
# Unnamed: 23                                                NaN
# Unnamed: 24                                                NaN
# Unnamed: 25                                                NaN
#
#                                                              4
# created_at                                          06-12-2021
# LT                                                        30.0
# LB                                                        55.0
# KT                                                         2.0
# KM                                                         2.0
# garasi                                                     NaN
# carport                                                    1.0
# lokasi                                           Jakarta Pusat
# sertifikat                                                 SHM
# listrik                                                 2200.0
# hadap                                                      NaN
# harga                                             1100000000.0
# URL          https://www.rumah.com/listing-properti/dijual-...
# deskripsi    Bisa request ubah tata ruang, beli 2 unit mend...
# Unnamed: 14                                                NaN
# Unnamed: 15                                                NaN
# Unnamed: 16                                                NaN
# Unnamed: 17                                                NaN
# Unnamed: 18                                                NaN
# Unnamed: 19                                                NaN
# Unnamed: 20                                                NaN
# Unnamed: 21                                                NaN
# Unnamed: 22                                                NaN
# Unnamed: 23                                                NaN
# Unnamed: 24                                                NaN
# Unnamed: 25                                                NaN

# %%
dfDepok.head().T
# Out:
#                                                              0  \
# created_at                                           6-12-2021
# LT                                                         165
# LB                                                       200.0
# KT                                                         4.0
# KM                                                         2.0
# garasi                                                     NaN
# carport                                                    1.0
# lokasi                                               Sukmajaya
# sertifikat                                                 SHM
# listrik                                                 2200.0
# hadap                                                  Selatan
# harga                                                   2100.0
# URL          https://www.rumah123.com/properti/depok/hos928...
# deskripsi                        Rumah siap huni komplek Pelni
# Unnamed: 14                                                NaN
# Unnamed: 15                                                NaN
# Unnamed: 16                                                NaN
# Unnamed: 17                                                NaN
# Unnamed: 18                                                NaN
# Unnamed: 19                                                NaN
# Unnamed: 20                                                NaN
# Unnamed: 21                                                NaN
# Unnamed: 22                                                NaN
# Unnamed: 23                                                NaN
# Unnamed: 24                                                NaN
# Unnamed: 25                                                NaN
#
#                                                              1  \
# created_at                                           6-12-2021
# LT                                                          50
# LB                                                        45.0
# KT                                                         2.0
# KM                                                         1.0
# garasi                                                     NaN
# carport                                                    NaN
# lokasi                                                Cipayung
# sertifikat                                                 SHM
# listrik                                                 1300.0
# hadap                                                      NaN
# harga                                                    250.0
# URL          https://www.rumah123.com/properti/depok/hos928...
# deskripsi                  rumah minimalis termurah di citayam
# Unnamed: 14                                                NaN
# Unnamed: 15                                                NaN
# Unnamed: 16                                                NaN
# Unnamed: 17                                                NaN
# Unnamed: 18                                                NaN
# Unnamed: 19                                                NaN
# Unnamed: 20                                                NaN
# Unnamed: 21                                                NaN
# Unnamed: 22                                                NaN
# Unnamed: 23                                                NaN
# Unnamed: 24                                                NaN
# Unnamed: 25                                                NaN
#
#                                                              2  \
# created_at                                           6-12-2021
# LT                                                          50
# LB                                                        36.0
# KT                                                         2.0
# KM                                                         1.0
# garasi                                                     NaN
# carport                                                    1.0
# lokasi                                                Sawangan
# sertifikat                                                 SHM
# listrik                                                 1300.0
# hadap                                                    Barat
# harga                                                    250.0
# URL          https://www.rumah123.com/properti/depok/hos928...
# deskripsi              CLUSTER TERMURAH DI SAWANGAN KOTA DEPOK
# Unnamed: 14                                                NaN
# Unnamed: 15                                                NaN
# Unnamed: 16                                                NaN
# Unnamed: 17                                                NaN
# Unnamed: 18                                                NaN
# Unnamed: 19                                                NaN
# Unnamed: 20                                                NaN
# Unnamed: 21                                                NaN
# Unnamed: 22                                                NaN
# Unnamed: 23                                                NaN
# Unnamed: 24                                                NaN
# Unnamed: 25                                                NaN
#
#                                                              3  \
# created_at                                           6-12-2021
# LT                                                          50
# LB                                                        45.0
# KT                                                         2.0
# KM                                                         1.0
# garasi                                                     NaN
# carport                                                    NaN
# lokasi                                               Cimanggis
# sertifikat                                                 SHM
# listrik                                                 1300.0
# hadap                                                      NaN
# harga                                                    250.0
# URL          https://www.rumah123.com/properti/depok/hos928...
# deskripsi     RUMAH SIAP HUNI HARGA NEGO DEKAT STASIUN CITAYAM
# Unnamed: 14                                                NaN
# Unnamed: 15                                                NaN
# Unnamed: 16                                                NaN
# Unnamed: 17                                                NaN
# Unnamed: 18                                                NaN
# Unnamed: 19                                                NaN
# Unnamed: 20                                                NaN
# Unnamed: 21                                                NaN
# Unnamed: 22                                                NaN
# Unnamed: 23                                                NaN
# Unnamed: 24                                                NaN
# Unnamed: 25                                                NaN
#
#                                                              4
# created_at                                           6-12-2021
# LT                                                          72
# LB                                                        45.0
# KT                                                         2.0
# KM                                                         1.0
# garasi                                                     NaN
# carport                                                    1.0
# lokasi                                                Sawangan
# sertifikat                                                 SHM
# listrik                                                 1300.0
# hadap                                                    Timur
# harga                                                    350.0
# URL          https://www.rumah123.com/properti/depok/hos928...
# deskripsi                        Rumah Cluster Siap Huni Depok
# Unnamed: 14                                                NaN
# Unnamed: 15                                                NaN
# Unnamed: 16                                                NaN
# Unnamed: 17                                                NaN
# Unnamed: 18                                                NaN
# Unnamed: 19                                                NaN
# Unnamed: 20                                                NaN
# Unnamed: 21                                                NaN
# Unnamed: 22                                                NaN
# Unnamed: 23                                                NaN
# Unnamed: 24                                                NaN
# Unnamed: 25                                                NaN

# %%
dfBogor.head().T
# Out:
#                                                              0  \
# created_at                                          03-12-2021
# LT                                                        75.0
# LB                                                        38.0
# KT                                                         2.0
# KM                                                         1.0
# garasi                                                     1.0
# carport                                                    1.0
# lokasi                                              Bojonggede
# sertifikat                                                 SHM
# listrik                                                 1300.0
# hadap                                                    Barat
# harga                                              692550000.0
# URL          https://rumahdijual.com/bekasi/10799791-rumah-...
# deskripsi    Dekat tol jati warna, dekat sutle busway, deka...
# Unnamed: 14                                                NaN
# Unnamed: 15                                                NaN
# Unnamed: 16                                                NaN
# Unnamed: 17                                                NaN
# Unnamed: 18                                                NaN
# Unnamed: 19                                                NaN
# Unnamed: 20                                                NaN
# Unnamed: 21                                                NaN
# Unnamed: 22                                                NaN
# Unnamed: 23                                                NaN
# Unnamed: 24                                                NaN
# Unnamed: 25                                                NaN
#
#                                                              1  \
# created_at                                          06-12-2021
# LT                                                        60.0
# LB                                                        40.0
# KT                                                         1.0
# KM                                                         1.0
# garasi                                                     0.0
# carport                                                    1.0
# lokasi                                          Babakan Madang
# sertifikat                                                 SHM
# listrik                                                 2200.0
# hadap                                                      NaN
# harga                                              811400000.0
# URL          https://www.rumah123.com/perumahan-baru/proper...
# deskripsi    Destinasi menarik di kawasan Babakan Madang; G...
# Unnamed: 14                                                NaN
# Unnamed: 15                                                NaN
# Unnamed: 16                                                NaN
# Unnamed: 17                                                NaN
# Unnamed: 18                                                NaN
# Unnamed: 19                                                NaN
# Unnamed: 20                                                NaN
# Unnamed: 21                                                NaN
# Unnamed: 22                                                NaN
# Unnamed: 23                                                NaN
# Unnamed: 24                                                NaN
# Unnamed: 25                                                NaN
#
#                                                              2  \
# created_at                                          06-12-2021
# LT                                                        60.0
# LB                                                        50.0
# KT                                                         2.0
# KM                                                         2.0
# garasi                                                     0.0
# carport                                                    1.0
# lokasi                                          Babakan Madang
# sertifikat                                                 SHM
# listrik                                                 2200.0
# hadap                                                      NaN
# harga                                              900500000.0
# URL          https://www.rumah123.com/perumahan-baru/proper...
# deskripsi    Destinasi menarik di kawasan Babakan Madang; G...
# Unnamed: 14                                                NaN
# Unnamed: 15                                                NaN
# Unnamed: 16                                                NaN
# Unnamed: 17                                                NaN
# Unnamed: 18                                                NaN
# Unnamed: 19                                                NaN
# Unnamed: 20                                                NaN
# Unnamed: 21                                                NaN
# Unnamed: 22                                                NaN
# Unnamed: 23                                                NaN
# Unnamed: 24                                                NaN
# Unnamed: 25                                                NaN
#
#                                                              3  \
# created_at                                          06-12-2021
# LT                                                        60.0
# LB                                                        70.0
# KT                                                         3.0
# KM                                                         2.0
# garasi                                                     0.0
# carport                                                    1.0
# lokasi                                          Babakan Madang
# sertifikat                                                 SHM
# listrik                                                 2200.0
# hadap                                                      NaN
# harga                                             1001900000.0
# URL          https://www.rumah123.com/perumahan-baru/proper...
# deskripsi    Destinasi menarik di kawasan Babakan Madang; G...
# Unnamed: 14                                                NaN
# Unnamed: 15                                                NaN
# Unnamed: 16                                                NaN
# Unnamed: 17                                                NaN
# Unnamed: 18                                                NaN
# Unnamed: 19                                                NaN
# Unnamed: 20                                                NaN
# Unnamed: 21                                                NaN
# Unnamed: 22                                                NaN
# Unnamed: 23                                                NaN
# Unnamed: 24                                                NaN
# Unnamed: 25                                                NaN
#
#                                                              4
# created_at                                          06-12-2021
# LT                                                        90.0
# LB                                                        60.0
# KT                                                         3.0
# KM                                                         2.0
# garasi                                                     0.0
# carport                                                    2.0
# lokasi                                          Babakan Madang
# sertifikat                                                 SHM
# listrik                                                 2200.0
# hadap                                                      NaN
# harga                                             1200800000.0
# URL          https://www.rumah123.com/perumahan-baru/proper...
# deskripsi    Destinasi menarik di kawasan Babakan Madang; G...
# Unnamed: 14                                                NaN
# Unnamed: 15                                                NaN
# Unnamed: 16                                                NaN
# Unnamed: 17                                                NaN
# Unnamed: 18                                                NaN
# Unnamed: 19                                                NaN
# Unnamed: 20                                                NaN
# Unnamed: 21                                                NaN
# Unnamed: 22                                                NaN
# Unnamed: 23                                                NaN
# Unnamed: 24                                                NaN
# Unnamed: 25                                                NaN

# %%
dfTangerang.head().T
# Out:
#                                                              0  \
# created_at                                          12-06-2021
# LT                                                        60.0
# LB                                                        50.0
# KT                                                         3.0
# KM                                                         2.0
# garasi                                                     NaN
# carport                                                    NaN
# lokasi                                     BSD CITY, TANGERANG
# sertifikat                                                 SHM
# listrik                                                 1300.0
# hadap                                                  Selatan
# harga                                                    500.0
# URL          https://www.rumah123.com/properti/tangerang/ho...
# deskripsi    Rumah 2 Lantai Akses Strategis, Keamanan 24jam...
# Unnamed: 14                                                NaN
# Unnamed: 15                                                NaN
# Unnamed: 16                                                NaN
# Unnamed: 17                                                NaN
# Unnamed: 18                                                NaN
# Unnamed: 19                                                NaN
# Unnamed: 20                                                NaN
# Unnamed: 21                                                NaN
# Unnamed: 22                                                NaN
# Unnamed: 23                                                NaN
# Unnamed: 24                                                NaN
# Unnamed: 25                                                NaN
#
#                                                              1  \
# created_at                                          12-06-2021
# LT                                                        72.0
# LB                                                        54.0
# KT                                                         2.0
# KM                                                         1.0
# garasi                                                     1.0
# carport                                                    1.0
# lokasi                                       CISAUK, TANGERANG
# sertifikat                                                 SHM
# listrik                                                 1300.0
# hadap                                                      NaN
# harga                                                    480.0
# URL          https://www.rumah123.com/properti/tangerang/ho...
# deskripsi    lokasi strategis dekat gading serpong, dekat a...
# Unnamed: 14                                                NaN
# Unnamed: 15                                                NaN
# Unnamed: 16                                                NaN
# Unnamed: 17                                                NaN
# Unnamed: 18                                                NaN
# Unnamed: 19                                                NaN
# Unnamed: 20                                                NaN
# Unnamed: 21                                                NaN
# Unnamed: 22                                                NaN
# Unnamed: 23                                                NaN
# Unnamed: 24                                                NaN
# Unnamed: 25                                                NaN
#
#                                                              2  \
# created_at                                          12-06-2021
# LT                                                        60.0
# LB                                                        48.0
# KT                                                         3.0
# KM                                                         2.0
# garasi                                                     2.0
# carport                                                    2.0
# lokasi                                      CILEDUG, TANGERANG
# sertifikat                                                 SHM
# listrik                                                 2200.0
# hadap                                                      NaN
# harga                                                    600.0
# URL          https://www.rumah123.com/properti/tangerang/ho...
# deskripsi    Boston Village Bintaro, Cluster dengan konsep ...
# Unnamed: 14                                                NaN
# Unnamed: 15                                                NaN
# Unnamed: 16                                                NaN
# Unnamed: 17                                                NaN
# Unnamed: 18                                                NaN
# Unnamed: 19                                                NaN
# Unnamed: 20                                                NaN
# Unnamed: 21                                                NaN
# Unnamed: 22                                                NaN
# Unnamed: 23                                                NaN
# Unnamed: 24                                                NaN
# Unnamed: 25                                                NaN
#
#                                                              3  \
# created_at                                          12-06-2021
# LT                                                       200.0
# LB                                                       225.0
# KT                                                         5.0
# KM                                                         4.0
# garasi                                                     NaN
# carport                                                    NaN
# lokasi                               LIPPO KARAWACI, TANGERANG
# sertifikat                                                 SHM
# listrik                                                 5500.0
# hadap                                                      NaN
# harga                                                   4250.0
# URL          https://www.rumah123.com/properti/tangerang/ho...
# deskripsi    DIJUAL RUMAH BARU SELESAI DIBANGUN, LIPPO KARA...
# Unnamed: 14                                                NaN
# Unnamed: 15                                                NaN
# Unnamed: 16                                                NaN
# Unnamed: 17                                                NaN
# Unnamed: 18                                                NaN
# Unnamed: 19                                                NaN
# Unnamed: 20                                                NaN
# Unnamed: 21                                                NaN
# Unnamed: 22                                                NaN
# Unnamed: 23                                                NaN
# Unnamed: 24                                                NaN
# Unnamed: 25                                                NaN
#
#                                                              4
# created_at                                          12-06-2021
# LT                                                        76.0
# LB                                                       123.0
# KT                                                         3.0
# KM                                                         3.0
# garasi                                                     NaN
# carport                                                    2.0
# lokasi                                  PONDOK CABE, TANGERANG
# sertifikat                                                 SHM
# listrik                                                 2200.0
# hadap                                                      NaN
# harga                                                   1700.0
# URL          https://www.rumah123.com/properti/tangerang/ho...
# deskripsi    diapit oleh 3 tol besar, JOR 2, Cinere-Jagoraw...
# Unnamed: 14                                                NaN
# Unnamed: 15                                                NaN
# Unnamed: 16                                                NaN
# Unnamed: 17                                                NaN
# Unnamed: 18                                                NaN
# Unnamed: 19                                                NaN
# Unnamed: 20                                                NaN
# Unnamed: 21                                                NaN
# Unnamed: 22                                                NaN
# Unnamed: 23                                                NaN
# Unnamed: 24                                                NaN
# Unnamed: 25                                                NaN

# %%
dfBekasi.head().T
# Out:
#                                                              0  \
# created_at                                          08-12-2021
# LT                                                        71.0
# LB                                                        43.0
# KT                                                         2.0
# KM                                                         1.0
# garasi                                                     NaN
# carport                                                    1.0
# lokasi                                        Kabupaten Bekasi
# sertifikat                                                 SHM
# listrik                                                 1300.0
# hadap                                                      NaN
# harga                                              550000000.0
# URL          Rumah murah di metland cibitung bekasi - Dijua...
# deskripsi    Selangkah ke stasiun krl telaga murni, Dekat d...
# Unnamed: 14                                                NaN
# Unnamed: 15                                                NaN
# Unnamed: 16                                                NaN
# Unnamed: 17                                                NaN
# Unnamed: 18                                                NaN
# Unnamed: 19                                                NaN
# Unnamed: 20                                                NaN
# Unnamed: 21                                                NaN
# Unnamed: 22                                                NaN
# Unnamed: 23                                                NaN
# Unnamed: 24                                                NaN
# Unnamed: 25                                                NaN
#
#                                                              1  \
# created_at                                          08-12-2021
# LT                                                        59.0
# LB                                                        60.0
# KT                                                         2.0
# KM                                                         1.0
# garasi                                                     NaN
# carport                                                    1.0
# lokasi                                        Kabupaten Bekasi
# sertifikat                                                 SHM
# listrik                                                    NaN
# hadap                                                      NaN
# harga                                              440000000.0
# URL          Rumah dijual di Griya gandasari cibitung - Dij...
# deskripsi    Rumah sangat nyaman,dan terbukti bebas banjir,...
# Unnamed: 14                                                NaN
# Unnamed: 15                                                NaN
# Unnamed: 16                                                NaN
# Unnamed: 17                                                NaN
# Unnamed: 18                                                NaN
# Unnamed: 19                                                NaN
# Unnamed: 20                                                NaN
# Unnamed: 21                                                NaN
# Unnamed: 22                                                NaN
# Unnamed: 23                                                NaN
# Unnamed: 24                                                NaN
# Unnamed: 25                                                NaN
#
#                                                              2  \
# created_at                                          08-12-2021
# LT                                                       124.0
# LB                                                        95.0
# KT                                                         2.0
# KM                                                         1.0
# garasi                                                     NaN
# carport                                                    1.0
# lokasi                                        Kabupaten Bekasi
# sertifikat                                                 SHM
# listrik                                                    NaN
# hadap                                                      NaN
# harga                                              699000000.0
# URL          Jual cepat rumah huuk di metland cibitung beka...
# deskripsi    Bebas banjir, Carport dan tanah luas ada taman...
# Unnamed: 14                                                NaN
# Unnamed: 15                                                NaN
# Unnamed: 16                                                NaN
# Unnamed: 17                                                NaN
# Unnamed: 18                                                NaN
# Unnamed: 19                                                NaN
# Unnamed: 20                                                NaN
# Unnamed: 21                                                NaN
# Unnamed: 22                                                NaN
# Unnamed: 23                                                NaN
# Unnamed: 24                                                NaN
# Unnamed: 25                                                NaN
#
#                                                              3  \
# created_at                                          08-12-2021
# LT                                                       144.0
# LB                                                       100.0
# KT                                                         2.0
# KM                                                         1.0
# garasi                                                     NaN
# carport                                                    1.0
# lokasi                                        Kabupaten Bekasi
# sertifikat                                                 SHM
# listrik                                                 2200.0
# hadap                                                  Selatan
# harga                                             1350000000.0
# URL          https://www.realoka.com/216243-rumah-rapi-siap...
# deskripsi    (Harapan Indah) Cluster Aralia Kota Harapan In...
# Unnamed: 14                                                NaN
# Unnamed: 15                                                NaN
# Unnamed: 16                                                NaN
# Unnamed: 17                                                NaN
# Unnamed: 18                                                NaN
# Unnamed: 19                                                NaN
# Unnamed: 20                                                NaN
# Unnamed: 21                                                NaN
# Unnamed: 22                                                NaN
# Unnamed: 23                                                NaN
# Unnamed: 24                                                NaN
# Unnamed: 25                                                NaN
#
#                                                              4
# created_at                                          08-12-2021
# LT                                                       108.0
# LB                                                       100.0
# KT                                                         3.0
# KM                                                         2.0
# garasi                                                     NaN
# carport                                                    1.0
# lokasi                                        Kabupaten Bekasi
# sertifikat                                                 SHM
# listrik                                                 2200.0
# hadap                                                    Timur
# harga                                             1400000000.0
# URL          https://www.realoka.com/207964-jual-rumah-bagu...
# deskripsi    (Harapan Indah) Cluster Harmoni Perumahan Kota...
# Unnamed: 14                                                NaN
# Unnamed: 15                                                NaN
# Unnamed: 16                                                NaN
# Unnamed: 17                                                NaN
# Unnamed: 18                                                NaN
# Unnamed: 19                                                NaN
# Unnamed: 20                                                NaN
# Unnamed: 21                                                NaN
# Unnamed: 22                                                NaN
# Unnamed: 23                                                NaN
# Unnamed: 24                                                NaN
# Unnamed: 25                                                NaN

# %%
# Membuang baris kosong
dfJakarta.dropna(how = "all", inplace = True)
dfBogor.dropna(how = "all", inplace = True)
dfTangerang.dropna(how = "all", inplace = True)
dfBekasi.dropna(how = "all", inplace = True)
dfDepok.dropna(how = "all", inplace = True)

# %%
# Membuang kolom kosong
dfDepok.dropna(how = "all", axis = 1, inplace = True)
dfBogor.dropna(how = "all", axis = 1, inplace = True)
dfTangerang.dropna(how = "all", axis = 1, inplace = True)
dfBekasi.dropna(how = "all", axis = 1, inplace = True)
dfJakarta.dropna(how = "all", axis = 1, inplace = True)

# %%
# Setelah memeriksa sebagian data dengan perintah .head pada tiap wilayah di atas
# diperoleh indikasi adanya perbedaan format harga, sehingga akan diperiksa persebaran isi dari kolom harga dengan describe
for i in [dfJakarta, dfDepok, dfBogor, dfTangerang, dfBekasi]:
  print(i["harga"].describe())
# Out:
# count    1.210000e+02
# mean     8.985955e+09
# std      1.587610e+10
# min      3.800000e+08
# 25%      1.600000e+09
# 50%      3.400000e+09
# 75%      7.250000e+09
# max      1.050000e+11
# Name: harga, dtype: float64
# count     118.000000
# mean     1194.440678
# std      1474.387409
# min        41.000000
# 25%       485.000000
# 50%       810.000000
# 75%      1137.500000
# max      9000.000000
# Name: harga, dtype: float64
# count    1.930000e+02
# mean     1.289362e+09
# std      2.115854e+09
# min      6.500000e+07
# 25%      3.990000e+08
# 50%      6.700000e+08
# 75%      1.250000e+09
# max      1.650000e+10
# Name: harga, dtype: float64
# count       124.000000
# mean       3849.556452
# std        9316.413817
# min          95.000000
# 25%        1037.500000
# 50%        1950.000000
# 75%        3775.000000
# max      100000.000000
# Name: harga, dtype: float64
# count    1.070000e+02
# mean     1.074823e+09
# std      7.516152e+08
# min      1.600000e+08
# 25%      5.805000e+08
# 50%      9.200000e+08
# 75%      1.350000e+09
# max      4.500000e+09
# Name: harga, dtype: float64

# %%
# perhatikan bahwa pada wilayah depok dan tangerang terdapat perbadaan harga yang sangat jauh dibanding wilayah lainnya
# kami berasumsi terdapat kesalahan inputasi dimana harga di wilayah tersebut harusnya dalam satuan juta
# maka kami ubah format harga di wilayah lainnya ke dalam satuan juta juga
dfJakarta["harga"] = dfJakarta["harga"] / 1000000
dfBekasi["harga"] = dfBekasi["harga"] / 1000000
dfBogor["harga"] = dfBogor["harga"] / 1000000

# %%
for i in [dfJakarta, dfDepok, dfBogor, dfTangerang, dfBekasi]:
  print(i["harga"].describe())
# Out:
# count       121.000000
# mean       8985.954976
# std       15876.095204
# min         380.000000
# 25%        1600.000000
# 50%        3400.000000
# 75%        7250.000000
# max      105000.000000
# Name: harga, dtype: float64
# count     118.000000
# mean     1194.440678
# std      1474.387409
# min        41.000000
# 25%       485.000000
# 50%       810.000000
# 75%      1137.500000
# max      9000.000000
# Name: harga, dtype: float64
# count      193.000000
# mean      1289.361525
# std       2115.853975
# min         65.000000
# 25%        399.000000
# 50%        670.000000
# 75%       1250.000000
# max      16500.000000
# Name: harga, dtype: float64
# count       124.000000
# mean       3849.556452
# std        9316.413817
# min          95.000000
# 25%        1037.500000
# 50%        1950.000000
# 75%        3775.000000
# max      100000.000000
# Name: harga, dtype: float64
# count     107.000000
# mean     1074.823355
# std       751.615160
# min       160.000000
# 25%       580.500000
# 50%       920.000000
# 75%      1350.000000
# max      4500.000000
# Name: harga, dtype: float64

# %%
# Memberikan informasi baru pada data di setiap wilayah berupa nama wilayahnya
dfJakarta["wilayah"] = "Jakarta"
dfDepok["wilayah"] = "Depok"
dfBogor["wilayah"] = "Bogor"
dfTangerang["wilayah"] = "Tangerang"
dfBekasi["wilayah"] = "Bekasi"

# %%
# Menggabungkan data semua wilayah
dfgabungan = pd.concat([dfJakarta, dfBogor, dfBekasi, dfTangerang, dfDepok], axis = 0, ignore_index=True)
dfgabungan
# Out:
#      created_at                                               LT     LB   KT  \
# 0    06-12-2021                                            202.0  198.0  8.0
# 1    02-12-2021                                             30.0   55.0  2.0
# 2    06-12-2021                                             19.0   35.0  2.0
# 3    06-12-2021                                             33.0   42.0  2.0
# 4    06-12-2021                                             30.0   55.0  2.0
# ..          ...                                              ...    ...  ...
# 660   4-12-2021                                               40   40.0  2.0
# 661   4-12-2021                                               50   50.0  2.0
# 662   4-12-2021                                              100   15.0  3.0
# 663       NOTE:   - lokasi yang kami gunakan hanya per kecamatan    NaN  NaN
# 664         NaN  -harga yang kami gunakan adalah per satuan juta    NaN  NaN
#
#       KM  garasi  carport         lokasi sertifikat  listrik    hadap   harga  \
# 0    3.0     NaN      NaN  Jakarta Pusat        SHM   2200.0      NaN  4500.0
# 1    1.0     NaN      1.0  Jakarta Pusat        SHM   2200.0      NaN  1100.0
# 2    1.0     NaN      NaN  Jakarta Pusat        SHM   2200.0      NaN   395.0
# 3    2.0     NaN      1.0  Jakarta Pusat        SHM   2200.0      NaN   835.0
# 4    2.0     NaN      1.0  Jakarta Pusat        SHM   2200.0      NaN  1100.0
# ..   ...     ...      ...            ...        ...      ...      ...     ...
# 660  1.0     NaN      NaN       Cipayung        SHM   1300.0    Timur   195.0
# 661  1.0     NaN      NaN       Cipayung        SHM   1300.0  Selatan   185.0
# 662  3.0     1.0      1.0         Cinere        SHM   3500.0      NaN  1750.0
# 663  NaN     NaN      NaN            NaN        NaN      NaN      NaN     NaN
# 664  NaN     NaN      NaN            NaN        NaN      NaN      NaN     NaN
#
#                                                    URL  \
# 0    https://www.rumah.com/listing-properti/dijual-...
# 1    https://www.rumah.com/listing-properti/dijual-...
# 2    https://www.rumah.com/listing-properti/dijual-...
# 3    https://www.rumah.com/listing-properti/dijual-...
# 4    https://www.rumah.com/listing-properti/dijual-...
# ..                                                 ...
# 660  https://www.rumah123.com/properti/depok/hos928...
# 661  https://www.rumah123.com/properti/depok/hos927...
# 662  https://www.rumah123.com/properti/depok/hos928...
# 663                                                NaN
# 664                                                NaN
#
#                                              deskripsi  wilayah
# 0    Dekat Cikini Salemba Taman Isamail Marzuki Kam...  Jakarta
# 1    Mengusung konsep minimalis, dan didukung denga...  Jakarta
# 2    Dekat dengan Mall Atrium Senen, dekat dengan a...  Jakarta
# 3    Berlokasi sangat strategis, sangat dekat ke Tu...  Jakarta
# 4    Bisa request ubah tata ruang, beli 2 unit mend...  Jakarta
# ..                                                 ...      ...
# 660  rumah semi minimalis manis harga ekonomis di c...    Depok
# 661  rumah semi minimalis dua kamar siap huni di ci...    Depok
# 662                 Dijual cepat rumah bagus siap huni    Depok
# 663                                                NaN    Depok
# 664                                                NaN    Depok
#
# [665 rows x 15 columns]

# %%
dfgabungan.shape # melihat dimensi data
# Out:
# (665, 15)

# %%
# Memeriksa kolom created_at
wilayah = ["Jakarta", "Depok", "Bogor", "Tangerang", "Bekasi"]
for i in wilayah:
  print(i)
  print(dfgabungan[dfgabungan["wilayah"] == i]["created_at"].unique())
# Out:
# Jakarta
# ['06-12-2021' '02-12-2021' '05-12-2021' '07-12-2021' '07-11-2021'
#  '01-12-2021' '18-11-2021' '04-12-2021' '29-11-2021' '22-11-2021'
#  '15-11-2021' '06-11-2021' '16-11-2021' '03-12-2021' '06-10-2021'
#  '12-02-2021' '26-12-2021' '25-11-2021' '24-11-2021']
# Depok
# ['6-12-2021' '5-12-2021' '4-12-2021' 'NOTE:' nan]
# Bogor
# ['03-12-2021' '06-12-2021' '07-12-2021' '02-12-2021' '01-12-2021'
#  '04-12-2021' '05-12-2021']
# Tangerang
# ['12-06-2021' '12-07-2021' '12-08-2021']
# Bekasi
# ['08-12-2021' '07-12-2021' '06-12-2021' '05-12-2021' '04-12-2021'
#  '03-12-2021' '02-12-2021' '01-12-2021']

# %% [markdown]
# Dikarenakan isi kolom created_at kurang relevan dengan data, maka akan dilakukan penghapusan pada kolom tersebut.
#
# Namun memberikan informasi bahwa data dikumpulkan pada beberapa periode waktu tertentu pada setiap daerahnya.

# %%
dfgabungan.drop(["created_at"], axis = 1, inplace = True)

# %%
dfgabungan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 665 entries, 0 to 664
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LT          665 non-null    object
#  1   LB          663 non-null    float64
#  2   KT          663 non-null    float64
#  3   KM          662 non-null    float64
#  4   garasi      333 non-null    float64
#  5   carport     550 non-null    float64
#  6   lokasi      663 non-null    object
#  7   sertifikat  658 non-null    object
#  8   listrik     628 non-null    float64
#  9   hadap       214 non-null    object
#  10  harga       663 non-null    float64
#  11  URL         663 non-null    object
#  12  deskripsi   654 non-null    object
#  13  wilayah     665 non-null    object
# dtypes: float64(7), object(7)
# memory usage: 72.9+ KB

# %% [markdown]
# Perhatikan kolom LT memiliki tipe data object, yang mana seharusnya berisikan luas tanah berupa nilai numerik (float64). Sehingga dilakukan pemeriksaan nilai pada kolom tersebut.

# %%
dfgabungan["LT"].unique()
# Out:
# array([202.0, 30.0, 19.0, 33.0, 217.0, 424.0, 597.0, 60.0, 71.0, 75.0,
#        45.0, 24.0, 3422.0, 23.0, 50.0, 652.0, 840.0, 21.0, 16.0, 700.0,
#        18.0, 1000.0, 189.0, 390.0, 124.0, 225.0, 290.0, 432.0, 243.0,
#        239.0, 130.0, 97.0, 485.0, 90.0, 511.0, 205.0, 695.0, 135.0, 612.0,
#        790.0, 950.0, 738.0, 719.0, 85.0, 47.0, 160.0, 84.0, 147.0, 49.0,
#        52.0, 79.0, 140.0, 400.0, 119.0, 184.0, 863.0, 120.0, 500.0, 200.0,
#        128.0, 300.0, 168.0, 170.0, 98.0, 330.0, 144.0, 260.0, 162.0, 36.0,
#        150.0, 240.0, 250.0, 175.0, 375.0, 320.0, 640.0, 80.0, 232.0,
#        153.0, 317.0, 95.0, 100.0, 72.0, 112.0, 69.0, 109.0, 86.0, 96.0,
#        67.0, 122.0, 220.0, 70.0, 315.0, 125.0, 312.0, 105.0, 78.0, 1500.0,
#        699.0, 66.0, 314.0, 1272.0, 338.0, 62.0, 196.0, 167.0, 91.0, 108.0,
#        210.0, 156.0, 255.0, 270.0, 800.0, 280.0, 276.0, 437.0, 106.0,
#        180.0, 867.0, 696.0, 698.0, 81.0, 65.0, 93.0, 38.0, 102.0, 188.0,
#        470.0, 195.0, 142.0, 89.0, 313.0, 131.0, 345.0, 206.0, 1058.0,
#        74.0, 107.0, 59.0, 336.0, 77.0, 245.0, 296.0, 94.0, 88.0, 110.0,
#        54.0, 63.0, 117.0, 101.0, 143.0, 126.0, 145.0, 364.0, 76.0, 37.0,
#        151.0, 224.0, 216.0, 265.0, 155.0, 534.0, 295.0, 385.0, 625.0,
#        474.0, 335.0, 241.0, 234.0, 48.0, 99.0, 230.0, 136.0, 113.0, 373.0,
#        365.0, 3087.0, 308.0, 288.0, 118.0, '165', '50', '72', '40', '45',
#        '36', '87', '210', '60', '70', '200', '57', '100', '97', '112',
#        '84', '75', '487', '378', '400', '77', '1024', '120', '151', '885',
#        '54', '249', '76', '66', '79', '78', '105', '63', '62', '71', '92',
#        '96', '65', '104', '110', '64', '51', '85', '81', '59', '88', '47',
#        '55', '82', '185', '880', '74', '335', '83', '94', '80',
#        '- lokasi yang kami gunakan hanya per kecamatan',
#        '-harga yang kami gunakan adalah per satuan juta'], dtype=object)

# %%
dfgabungan[(dfgabungan["LT"] == '- lokasi yang kami gunakan hanya per kecamatan') | (dfgabungan["LT"] == '-harga yang kami gunakan adalah per satuan juta')]
dfgabungan[dfgabungan["LT"].isin(['- lokasi yang kami gunakan hanya per kecamatan',  '-harga yang kami gunakan adalah per satuan juta'])]
# Out:
#                                                   LT  LB  KT  KM  garasi  \
# 663   - lokasi yang kami gunakan hanya per kecamatan NaN NaN NaN     NaN
# 664  -harga yang kami gunakan adalah per satuan juta NaN NaN NaN     NaN
#
#      carport lokasi sertifikat  listrik hadap  harga  URL deskripsi wilayah
# 663      NaN    NaN        NaN      NaN   NaN    NaN  NaN       NaN   Depok
# 664      NaN    NaN        NaN      NaN   NaN    NaN  NaN       NaN   Depok

# %% [markdown]
# Terdeteksi adanya noise berupa nilai non-numeric pada kolom yang seharusnya numerik. Begitu pula pada baris data tersebut tidak ditemukan informasi yang bermanfaat (hanya NaN), sehingga baris-baris tersebut dapat kita hapus.

# %%
dfgabungan.drop(dfgabungan[dfgabungan["LT"].isin(['- lokasi yang kami gunakan hanya per kecamatan',  '-harga yang kami gunakan adalah per satuan juta'])].index, inplace = True)

# %%
dfgabungan["LT"] = dfgabungan["LT"].astype("float64")
dfgabungan["lokasi"] = dfgabungan["lokasi"].astype("category")
dfgabungan["wilayah"] = dfgabungan["wilayah"].astype("category")

# %%
dfgabungan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 663 entries, 0 to 662
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LT          663 non-null    float64
#  1   LB          663 non-null    float64
#  2   KT          663 non-null    float64
#  3   KM          662 non-null    float64
#  4   garasi      333 non-null    float64
#  5   carport     550 non-null    float64
#  6   lokasi      663 non-null    category
#  7   sertifikat  658 non-null    object
#  8   listrik     628 non-null    float64
#  9   hadap       214 non-null    object
#  10  harga       663 non-null    float64
#  11  URL         663 non-null    object
#  12  deskripsi   654 non-null    object
#  13  wilayah     663 non-null    category
# dtypes: category(2), float64(8), object(4)
# memory usage: 66.5+ KB

# %%
dfgabungan.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Tidak ditemukan adanya duplikasi data pada keseluruhan kolom.

# %%
# Memeriksa missing value dengan heatmap
sns.heatmap(dfgabungan.isnull(), cbar=False)
plt.title('Heatmap Missing Value')
plt.show()

# %%
# persentase missing value
dfgabungan.isnull().sum()/len(dfgabungan)*100
# Out:
# LT             0.000000
# LB             0.000000
# KT             0.000000
# KM             0.150830
# garasi        49.773756
# carport       17.043741
# lokasi         0.000000
# sertifikat     0.754148
# listrik        5.279035
# hadap         67.722474
# harga          0.000000
# URL            0.000000
# deskripsi      1.357466
# wilayah        0.000000
# dtype: float64

# %%
# Penanganan MV
# asumsi MV pada KM, garasi, carport sebagai tidak punya alias 0
dfgabungan["KM"].fillna(0, inplace = True)
dfgabungan["garasi"].fillna(0, inplace = True)
dfgabungan["carport"].fillna(0, inplace = True)

# asumsi MV pada sertifikat sebagai Lainnya
dfgabungan["sertifikat"].fillna("Lainnya", inplace = True)

# pemberian "-" untuk MV pada deskripsi dan hadap
dfgabungan["deskripsi"].fillna("-", inplace = True)
dfgabungan["hadap"].fillna("-", inplace = True)

# inputasi nilai median kolo listrik ke MV
dfgabungan["listrik"].fillna(dfgabungan["listrik"].median(), inplace = True)

# %%
# Kondisi heatmap setelah pananganan MV
sns.heatmap(dfgabungan.isnull(), cbar=False)
plt.title('Heatmap Missing Value')
plt.show()

# %%
dfgabungan.isnull().sum()/len(dfgabungan)*100
# Out:
# LT            0.0
# LB            0.0
# KT            0.0
# KM            0.0
# garasi        0.0
# carport       0.0
# lokasi        0.0
# sertifikat    0.0
# listrik       0.0
# hadap         0.0
# harga         0.0
# URL           0.0
# deskripsi     0.0
# wilayah       0.0
# dtype: float64

# %%
# Memeriksa Noise pada sertifikat
l = []
for i in wilayah:
  print(i)
  l += list(dfgabungan[dfgabungan["wilayah"] == i]["sertifikat"].unique())
  print(l)

k = []
for i in l:
  if i != "SHM":
    k.append(i)
k
# Out:
# Jakarta
# ['SHM', 'SHGB', 'SHM + IMB', 'SHM + IMB + PBB', 'SHM + Hak Pakai', 'PPJB', 'Lainnya', 'AJB']
# Depok
# ['SHM', 'SHGB', 'SHM + IMB', 'SHM + IMB + PBB', 'SHM + Hak Pakai', 'PPJB', 'Lainnya', 'AJB', 'SHM', 'Lainnya']
# Bogor
# ['SHM', 'SHGB', 'SHM + IMB', 'SHM + IMB + PBB', 'SHM + Hak Pakai', 'PPJB', 'Lainnya', 'AJB', 'SHM', 'Lainnya', 'SHM', 'SHGB', 'Lainnya']
# Tangerang
# ['SHM', 'SHGB', 'SHM + IMB', 'SHM + IMB + PBB', 'SHM + Hak Pakai', 'PPJB', 'Lainnya', 'AJB', 'SHM', 'Lainnya', 'SHM', 'SHGB', 'Lainnya', 'SHM', 'HGB', 'Lainnya', 'lainnya(PPJB, GIRIK, ADAT, dll)']
# Bekasi
# ['SHM', 'SHGB', 'SHM + IMB', 'SHM + IMB + PBB', 'SHM + Hak Pakai', 'PPJB', 'Lainnya', 'AJB', 'SHM', 'Lainnya', 'SHM', 'SHGB', 'Lainnya', 'SHM', 'HGB', 'Lainnya', 'lainnya(PPJB, GIRIK, ADAT, dll)', 'SHM', 'HGB', 'SHM,IMB', 'Lainnya']
# ['SHGB',
#  'SHM + IMB',
#  'SHM + IMB + PBB',
#  'SHM + Hak Pakai',
#  'PPJB',
#  'Lainnya',
#  'AJB',
#  'Lainnya',
#  'SHGB',
#  'Lainnya',
#  'HGB',
#  'Lainnya',
#  'lainnya(PPJB, GIRIK, ADAT, dll)',
#  'HGB',
#  'SHM,IMB',
#  'Lainnya']

# %%
# penanganan Noise sertfikat
for i in k:
  dfgabungan["sertifikat"] = dfgabungan["sertifikat"].replace(i, "Lainnya")

# %%
list(dfgabungan["sertifikat"].unique()) # kondisi setelah penanganan noise
# Out:
# ['SHM', 'Lainnya']

# %%
# periksa noise pada URL apakah ada yang bukan link
urllist= list(dfgabungan["URL"].unique())
noturl = []
for i in urllist:
  if "http" not in i:
    noturl.append(i)
    print(i)
    noturl
# Out:
# Rumah murah di metland cibitung bekasi - Dijual: Rumah & Apartemen - 840087312 (olx.co.id)
# Rumah dijual di Griya gandasari cibitung - Dijual: Rumah & Apartemen - 840088652 (olx.co.id)
# Jual cepat rumah huuk di metland cibitung bekasi - Dijual: Rumah & Apartemen - 840592462 (olx.co.id)
# Rumah krem harga murah di Taman Wisma Asri 2 dekat Sumarecon Bekasi - Dijual: Rumah & Apartemen - 849295145 (olx.co.id)
# Rumah Bagus Full Renov di Harapan Indah Bekasi - Dijual: Rumah & Apartemen - 849293743 (olx.co.id)
# RUMAH FRESH MANIS SIAP HUNI di Taman Wanasari Indah Cibitung - Dijual: Rumah & Apartemen - 849215260 (olx.co.id)
# Rumah Cantik Siap Huni Tanah Luas Akses 2 Mobil Murah di Bekasi - hos9285628 | Rumah123.com

# %% [markdown]
# Terdapat Non-link pada kolom URL, namun ada domain dari tempat rumah tersebut dijual serta judul iklan. Oleh karena itu, menganggapnya bukan sebagai noise pada kolom tersebut.

# %%
# Memeriksa Outlier pada kolom Harga
sns.boxplot(x="harga", data=dfgabungan)
# Out:
# <Axes: xlabel='harga'>

# %%
# Mengolah outlier dengan median pada tiap wilayah dan memisahkannya dari data tanpa outlier
datagab_no_outlier = pd.DataFrame({
    'LT': [],         # Luas Tanah
    'LB': [],         # Luas Bangunan
    'KT': [],         # Kamar Tidur
    'KM': [],         # Kamar Mandi
    'garasi': [],     # Garasi
    'carport': [],    # Carport
    'lokasi': [],     # Lokasi
    'sertifikat': [], # Sertifikat (HGB/SHM)
    'listrik': [],    # Daya listrik
    'hadap': [],      # Arah rumah (hadap ke arah mana)
    'harga': [],      # Harga rumah
    'URL': [],        # Link URL properti
    'deskripsi': [],  # Deskripsi properti
    'wilayah': []     # Wilayah/lokasi geografis
})

datagab_outlier = pd.DataFrame({
    'LT': [],         # Luas Tanah
    'LB': [],         # Luas Bangunan
    'KT': [],         # Kamar Tidur
    'KM': [],         # Kamar Mandi
    'garasi': [],     # Garasi
    'carport': [],    # Carport
    'lokasi': [],     # Lokasi
    'sertifikat': [], # Sertifikat (HGB/SHM)
    'listrik': [],    # Daya listrik
    'hadap': [],      # Arah rumah (hadap ke arah mana)
    'harga': [],      # Harga rumah
    'URL': [],        # Link URL properti
    'deskripsi': [],  # Deskripsi properti
    'wilayah': []     # Wilayah/lokasi geografis
})

for i in wilayah:
  Q1harga = dfgabungan[dfgabungan["wilayah"] == i]["harga"].quantile(0.25)
  Q3harga = dfgabungan[dfgabungan["wilayah"] == i]["harga"].quantile(0.75)
  IQRharga = Q3harga - Q1harga

  lower_boundharga = Q1harga - 1.5 * IQRharga
  upper_boundharga = Q3harga + 1.5 * IQRharga

  bersih = (dfgabungan[dfgabungan["wilayah"] == i]["harga"] >= lower_boundharga) & (dfgabungan[dfgabungan["wilayah"] == i]["harga"] <= upper_boundharga)
  dfno_outlier = dfgabungan[dfgabungan["wilayah"] == i][bersih]
  dfoutlier = dfgabungan[dfgabungan["wilayah"] == i][~bersih]

  datagab_no_outlier = pd.concat([datagab_no_outlier, dfno_outlier], ignore_index=True) # Changed from dictionary to DataFrame
  datagab_outlier = pd.concat([datagab_outlier, dfoutlier], ignore_index=True) # Changed from dictionary to DataFrame
# Out:
# <ipython-input-359-2dee6cecd2be>:48: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   datagab_no_outlier = pd.concat([datagab_no_outlier, dfno_outlier], ignore_index=True) # Changed from dictionary to DataFrame
# <ipython-input-359-2dee6cecd2be>:48: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   datagab_no_outlier = pd.concat([datagab_no_outlier, dfno_outlier], ignore_index=True) # Changed from dictionary to DataFrame
# <ipython-input-359-2dee6cecd2be>:49: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   datagab_outlier = pd.concat([datagab_outlier, dfoutlier], ignore_index=True) # Changed from dictionary to DataFrame
# <ipython-input-359-2dee6cecd2be>:49: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   datagab_outlier = pd.concat([datagab_outlier, dfoutlier], ignore_index=True) # Changed from dictionary to DataFrame

# %%
datagab_no_outlier
# Out:
#         LT     LB   KT   KM  garasi  carport            lokasi sertifikat  \
# 0    202.0  198.0  8.0  3.0     0.0      0.0     Jakarta Pusat        SHM
# 1     30.0   55.0  2.0  1.0     0.0      1.0     Jakarta Pusat        SHM
# 2     19.0   35.0  2.0  1.0     0.0      0.0     Jakarta Pusat        SHM
# 3     33.0   42.0  2.0  2.0     0.0      1.0     Jakarta Pusat        SHM
# 4     30.0   55.0  2.0  2.0     0.0      1.0     Jakarta Pusat        SHM
# ..     ...    ...  ...  ...     ...      ...               ...        ...
# 599  180.0  220.0  5.0  3.0     0.0      0.0       Kota Bekasi        SHM
# 600  140.0  250.0  3.0  2.0     0.0      0.0  Kabupaten Bekasi        SHM
# 601   60.0   55.0  2.0  1.0     0.0      0.0  Kabupaten Bekasi        SHM
# 602   36.0   60.0  2.0  1.0     0.0      0.0  Kabupaten Bekasi        SHM
# 603   60.0   55.0  2.0  1.0     0.0      0.0  Kabupaten Bekasi        SHM
#
#      listrik    hadap   harga  \
# 0     2200.0        -  4500.0
# 1     2200.0        -  1100.0
# 2     2200.0        -   395.0
# 3     2200.0        -   835.0
# 4     2200.0        -  1100.0
# ..       ...      ...     ...
# 599   2200.0        -  1600.0
# 600   2200.0  Selatan   850.0
# 601   1300.0        -   250.0
# 602   1300.0    Timur   300.0
# 603   1300.0        -   250.0
#
#                                                    URL  \
# 0    https://www.rumah.com/listing-properti/dijual-...
# 1    https://www.rumah.com/listing-properti/dijual-...
# 2    https://www.rumah.com/listing-properti/dijual-...
# 3    https://www.rumah.com/listing-properti/dijual-...
# 4    https://www.rumah.com/listing-properti/dijual-...
# ..                                                 ...
# 599  https://www.rumah123.com/properti/bekasi/hos92...
# 600  https://www.rumah123.com/properti/bekasi/hos92...
# 601  https://www.rumah123.com/properti/bekasi/hos92...
# 602  https://www.rumah123.com/properti/bekasi/hos92...
# 603  https://www.rumah123.com/properti/bekasi/hos92...
#
#                                              deskripsi  wilayah
# 0    Dekat Cikini Salemba Taman Isamail Marzuki Kam...  Jakarta
# 1    Mengusung konsep minimalis, dan didukung denga...  Jakarta
# 2    Dekat dengan Mall Atrium Senen, dekat dengan a...  Jakarta
# 3    Berlokasi sangat strategis, sangat dekat ke Tu...  Jakarta
# 4    Bisa request ubah tata ruang, beli 2 unit mend...  Jakarta
# ..                                                 ...      ...
# 599  Akses pintu tol Bekasibarat; Dekat Mall Summar...   Bekasi
# 600  DIJUAL RUMAH, Taman Kebalen bekasi cluster, Ju...   Bekasi
# 601  Di jual Rumah Lelang Bank Pondok Ungu Permai, ...   Bekasi
# 602  Lokasi Super Strategis, Selangkah menuju Kota ...   Bekasi
# 603  RCG/20/V/010 MP/LB/THM/010 Di jual Rumah Lelan...   Bekasi
#
# [604 rows x 14 columns]

# %% [markdown]
# ## Insight

# %% [markdown]
# **Kualitas data yang dimiliki perusahaan.**
# - Data memiliki banyak missing value, tiap kota memiliki missing value lebih dari setengahnya.
# - Terdapat kolom dengan satuan numerik yang berbeda antar kota, yakni harga rumah kota depok dan Tangerang berbeda dengan kota lainnya.
# - Kurangnya keterangan tentang data, pada LB tidak diberitahukan tipe rumah berapa tingkat.
# - Terdapat entri format "lokasi" antar kota yang berbeda-beda, ada yang berdasarkan kecamatan, kota, bahkan nama jalan.

# %% [markdown]
# **Saran perbaikan data ke DE/DBA perusahaan agar RPPI menjadi data driven company yang unggul.**
# - Menerapkan format standar untuk semua data agar data menjadi lebih konsisten.
# - Menerapkan kebijakan tata kelola data yang ketat. Setiap tim, termasuk DE dan DBA, harus bertanggung jawab untuk menjaga kebersihan data. Termasuk menetapkan pedoman yang jelas tentang pengelolaan, pembaruan, dan pemeliharaan data.
# - Lebih spesifik dalam memberikan informasi tentang data.

# %%
# !pip install geopy
from geopy.geocoders import Nominatim

# Inisialisasi geocoder dengan user_agent yang lebih spesifik
geolocator = Nominatim(user_agent="my-geocoding-app") # Changed to a more descriptive user agent

data = {
    'longitude': [],
    'latitude': [],
    'mean': [] ,
    'wilayah': []
}
for i in wilayah:
  try:
    lokasi = geolocator.geocode(i)
    if lokasi:
      data['longitude'].append(lokasi.longitude)
      data['latitude'].append(lokasi.latitude)
      data['mean'].append(datagab_no_outlier[datagab_no_outlier["wilayah"] == i]["harga"].mean())
      data['wilayah'].append(i)
    else:
      print("Lokasi tidak ditemukan.")
  except GeocoderInsufficientPrivileges:
    print("Error: GeocoderInsufficientPrivileges. Periksa user-agent dan pastikan tidak melebihi batas permintaan.")
  except Exception as e:
    print(f"Error: {e}")

data = pd.DataFrame(data)
data
# Out:
# Requirement already satisfied: geopy in /usr/local/lib/python3.10/dist-packages (2.4.1)
# Requirement already satisfied: geographiclib<3,>=1.52 in /usr/local/lib/python3.10/dist-packages (from geopy) (2.0)
#     longitude  latitude         mean    wilayah
# 0  106.827049 -6.175247  3607.719543    Jakarta
# 1  106.815837 -6.407190   805.962963      Depok
# 2  107.001742 -6.545325   743.722841      Bogor
# 3  106.638216 -6.176192  2255.657895  Tangerang
# 4  106.994544 -6.234986   979.282515     Bekasi

# %%
import folium
# Inisialisasi peta folium (fokus pada lokasi pertama)
m = folium.Map(location=[-6.407190	, 106.815837], zoom_start=10)
colors = ['red', 'yellow', 'green', 'blue', 'purple']
# Tambahkan marker untuk setiap lokasi berdasarkan data
for idx, row in data[["latitude", "longitude", "mean"]].iterrows():
    folium.CircleMarker(
        location=[row['latitude'], row['longitude']],
        radius=row['mean']/80,  # Skala ukuran berdasarkan mean
        color = colors[idx],
        fill=True,
        fill_color=colors[idx],
        fill_opacity=0.6,
        popup=f"Mean: {row['mean']:.2f}"
    ).add_to(m)

# Simpan peta sebagai file HTML
m.save('map.html')

# Untuk menampilkan peta
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8269e1da9995fd20a4703519470f9347 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8269e1da9995fd20a4703519470f9347&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8269e1da9995fd20a4703519470f9347 = L.map(
#                 &quot;map_8269e1da9995fd20a4703519470f9347&quot;,
#                 {
#                     center: [-6.40719, 106.815837],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f908707b5ab90c77074bd89ee351a075 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f908707b5ab90c77074bd89ee351a075.addTo(map_8269e1da9995fd20a4703519470f9347);
#
#
#             var circle_marker_38159d6be885e3d713bcd32d3ff0f64b = L.circleMarker(
#                 [-6.175247, 106.8270488],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 45.096494292023806, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8269e1da9995fd20a4703519470f9347);
#
#
#         var popup_c8d03efbb0da9391a2f867ea310a756d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ccf979f8ccb4fcd0b7b23426899f8952 = $(`&lt;div id=&quot;html_ccf979f8ccb4fcd0b7b23426899f8952&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Mean: 3607.72&lt;/div&gt;`)[0];
#                 popup_c8d03efbb0da9391a2f867ea310a756d.setContent(html_ccf979f8ccb4fcd0b7b23426899f8952);
#
#
#
#         circle_marker_38159d6be885e3d713bcd32d3ff0f64b.bindPopup(popup_c8d03efbb0da9391a2f867ea310a756d)
#         ;
#
#
#
#
#             var circle_marker_26be0e1ddf90a033e8bda2d52227656f = L.circleMarker(
#                 [-6.40719, 106.8158371],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10.074537037037036, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8269e1da9995fd20a4703519470f9347);
#
#
#         var popup_31ad1c2cac00d61eb7bf09b49fbe69e9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_aa386f17f064fe2d7c60c17ca2b2bc3b = $(`&lt;div id=&quot;html_aa386f17f064fe2d7c60c17ca2b2bc3b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Mean: 805.96&lt;/div&gt;`)[0];
#                 popup_31ad1c2cac00d61eb7bf09b49fbe69e9.setContent(html_aa386f17f064fe2d7c60c17ca2b2bc3b);
#
#
#
#         circle_marker_26be0e1ddf90a033e8bda2d52227656f.bindPopup(popup_31ad1c2cac00d61eb7bf09b49fbe69e9)
#         ;
#
#
#
#
#             var circle_marker_a7f431461c0013e42d956cd63f7b0f8c = L.circleMarker(
#                 [-6.5453255, 107.00174246832204],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 9.296535514439654, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8269e1da9995fd20a4703519470f9347);
#
#
#         var popup_22b02a121e43e8084648cd86d7e77824 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b8707a13c8a6f1ba3d4109614e5d8469 = $(`&lt;div id=&quot;html_b8707a13c8a6f1ba3d4109614e5d8469&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Mean: 743.72&lt;/div&gt;`)[0];
#                 popup_22b02a121e43e8084648cd86d7e77824.setContent(html_b8707a13c8a6f1ba3d4109614e5d8469);
#
#
#
#         circle_marker_a7f431461c0013e42d956cd63f7b0f8c.bindPopup(popup_22b02a121e43e8084648cd86d7e77824)
#         ;
#
#
#
#
#             var circle_marker_abc0139fa8570878139487c055ea53d4 = L.circleMarker(
#                 [-6.1761924, 106.6382161],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;:

# %%
catp = sns.catplot(x = "wilayah", y = "harga", data = datagab_no_outlier)

# %% [markdown]
# **Dari data yang ada, apakah ada kecenderungan rumah disuatu kota lebih mahal/murah dibandingkan kota lain?**
#
# Berdasarkan map plot dan catplot di atas diperoleh terdapat kecenderungan harga rumah lebih mahal di wilayah Jakarta  dan harga lebih murah di wilayah Bogor, Bekasi, dan Depok.

# %% [markdown]
# **Dari data yang ada, apakah bisa dibuat rekomendasi sebaiknya RPPI membuat kantor cabang berikutnya di kota mana? Mengapa? (Asumsikan RPPI belum memiliki cabang di kota-kota yang disebutkan di data).**
#
# Berdasarkan analisis data yang ada, disarankan agar RPPI membuka kantor cabang berikutnya di Kota Depok. Berikut adalah alasan utama pemilihan lokasi ini:
#
# - Letak Geografis yang Strategis: Depok terletak di persimpangan berbagai wilayah penting di Jabodetabek, membuatnya lebih mudah diakses oleh klien dari berbagai daerah. Ini akan mempermudah interaksi dengan klien dan memperluas jangkauan pasar.
# - Rerata Harga Rumah yang Kompetitif: Rerata harga rumah di Depok relatif lebih terjangkau dibandingkan dengan Jakarta dan beberapa wilayah lainnya di Jabodetabek. Ini menjadikan Depok sebagai pilihan menarik bagi masyarakat yang mencari properti, serta memberikan peluang untuk investasi yang menguntungkan bagi RPPI.
# - Potensi Kolaborasi: Lokasi yang strategis di Depok memungkinkan RPPI untuk menjalin kemitraan dengan pengembang lokal dan perusahaan terkait lainnya, yang dapat meningkatkan visibilitas dan kredibilitas RPPI di pasar.
#
# Dengan mempertimbangkan faktor-faktor di atas, membuka kantor cabang di Kota Depok dapat menjadi langkah strategis yang tidak hanya meningkatkan jangkauan pasar RPPI tetapi juga memanfaatkan potensi pertumbuhan yang ada di wilayah tersebut.

# %%
dfgabungan[["LT", "LB", "KM", "KT", "garasi","carport"]].mode()
# Out:
#      LT    LB   KM   KT  garasi  carport
# 0  60.0  36.0  2.0  2.0     0.0      1.0

# %% [markdown]
# **Rumah dengan karakteristik seperti apa yang paling banyak dijual?**
#
# Interpretasi dari hasil ini adalah sebagai berikut:
#
# - LT (Luas Tanah): Nilai 60, yang berarti bahwa rumah dengan luas tanah 60 m² paling sering muncul dalam data penjualan.
# - LB (Luas Bangunan): Nilai 36, yang menunjukkan bahwa rumah dengan luas bangunan 36 m² paling sering terjual.
# - KM (Jumlah Kamar Mandi): Nilai 2, menunjukkan bahwa rumah dengan 2 kamar mandi paling sering terjual.
# - KT (Jumlah Kamar Tidur): Nilai 2, menunjukkan bahwa rumah dengan 2 kamar tidur paling sering terjual.
# - garasi: Nilai 0, menunjukkan bahwa rumah tanpa garasi paling sering terjual.
# - carport: Nilai 1, menunjukkan bahwa rumah dengan 1 carport paling sering terjual.
#
# Jadi, rumah dengan karakteristik yang paling sering terjual adalah rumah dengan luas tanah 60 m², luas bangunan 36 m², 2 kamar mandi, 2 kamar tidur, tanpa garasi, dan memiliki 1 carport.

# %%
filtered_df = dfgabungan[
    (dfgabungan['KM'] >= 1) & (dfgabungan['KM'] <= 2) &  # Kondisi untuk Kamar Mandi
    (dfgabungan['KT'] >= 1) & (dfgabungan['KT'] <= 3) &  # Kondisi untuk Kamar Tidur
    (dfgabungan['garasi'] >= 0) & (dfgabungan['garasi'] <= 1) &  # Kondisi untuk Garasi
    (dfgabungan['carport'] >= 1) & (dfgabungan['carport'] <= 2) &  # Kondisi untuk Carport
    (dfgabungan['LB'] >= 70) & (dfgabungan['LB'] <= 150) & # Kondisi untuk Luas Bangunan
    (dfgabungan['harga'] <= 900) & # Kondisi untuk Harga
    (dfgabungan['LT'] <= 100) # Kondisi untuk Wilayah
]
filtered_df.shape
# Out:
# (37, 14)

# %%
filtered_df['harga'].sum()
# Out:
# 24872.968

# %%
# menganalisa outlier dengan catplot
#catp = sns.catplot(x = "wilayah", y = "harga", data = filtered_df)
p = sns.scatterplot(y=filtered_df['harga'], x=filtered_df['LB'], hue = filtered_df['wilayah'])

# %% [markdown]
# **Jika RPPI ingin melakukan investasi (max) Rp. 25 Milyar minggu besok, apakah dari data anda dapat memberikan rekomendasi rumah mana saja yang akan berpotensi menghasilkan keuntungan bagi perusahaan?**
#
# Berdasarkan kriteria yang telah ditentukan dan hasil analisis, berikut adalah insight terkait investasi RPPI dengan maksimum anggaran Rp 25 Miliar:
#
# Insight Investasi untuk RPPI
#
# - Jumlah Properti Tersedia: Dari filter yang diterapkan, terdapat 37 rumah yang memenuhi kriteria yang ditentukan. Ini menunjukkan ada pilihan yang cukup untuk diinvestasikan, memberikan fleksibilitas dalam pemilihan properti.
# - Total Investasi: Total harga dari properti yang terfilter adalah Rp 24,87 Miliar. Ini masih di bawah batas maksimum investasi yang ditetapkan yaitu Rp 25 Miliar, sehingga RPPI masih memiliki ruang untuk memilih atau bahkan melakukan tawar-menawar untuk mendapatkan harga yang lebih baik jika diperlukan.
# - Karakteristik Properti:
# -- Kamar Mandi dan Kamar Tidur: Properti yang terpilih memiliki 1-2 kamar mandi dan 1-3 kamar tidur. Ini menunjukkan bahwa rumah-rumah ini cocok untuk keluarga kecil, sehingga dapat menarik pembeli atau penyewa yang mencari rumah dengan ukuran yang tidak terlalu besar.
# -- Garasi dan Carport: Dengan maksimum satu garasi dan dua carport, rumah-rumah ini dapat menarik pembeli yang memprioritaskan ruang parkir tetapi tidak membutuhkan banyak tempat parkir, sesuai dengan kebutuhan pasar di banyak kota.
# -- Luas Bangunan: Luas bangunan antara 70-150 m² menunjukkan bahwa properti ini sesuai untuk pasar menengah, menawarkan kenyamanan dengan biaya yang relatif terjangkau.
# -- Harga: Harga maksimum dari properti yang difilter adalah di bawah Rp 900 juta, sehingga tetap dalam jangkauan pembeli yang berada di segmen menengah ke bawah.
#
# Dengan karakteristik yang ada, investasi di rumah-rumah ini berpotensi menghasilkan keuntungan yang baik dalam jangka pendek hingga menengah, baik melalui penyewaan atau penjualan kembali.

# %%
# Memeriksa Outlier pada kolom Harga
sns.boxplot(x="harga", data=datagab_no_outlier)
# Out:
# <Axes: xlabel='harga'>

# %%
datagab_no_outlier["harga"].describe()
# Out:
# count      604.000000
# mean      1578.267261
# std       1838.246829
# min         41.000000
# 25%        500.000000
# 50%        920.000000
# 75%       1800.000000
# max      15000.000000
# Name: harga, dtype: float64

# %% [markdown]
# **Kisaran harga di wilayah jabodetabek**
#
# Meskipun telah dilakukan pemisahan outlier pada setiap wilayah jabodetabek, namun tetap ditemukan outlier yang cukup banyak, tetapi memiliki persebaran harga rumah di jabodetabek berkisar antara 41 juta sampai 4 miliar.

# %%
p = sns.scatterplot(x=datagab_outlier['harga'], y=datagab_outlier['LB'], hue = datagab_outlier['wilayah'])

# %%
p = sns.scatterplot(x=datagab_outlier['harga'], y=datagab_outlier['LT'], hue = datagab_outlier['wilayah'])

# %% [markdown]
# Berdasarkan dua plot di atas, terdapat informasi penting mengenai rumah dengan harga yang sangat tinggi di wilayah Jabodetabek:
#
# - Luas Bangunan dan Tanah: Kebanyakan rumah dengan harga tinggi memiliki luas bangunan dan luas tanah lebih dari 1.000 meter persegi, yang menunjukkan bahwa properti ini menawarkan ruang yang lebih luas dan potensi untuk pengembangan.
#
# - Potensi Harga:
# -- Di wilayah selain Jakarta, harga rumah berkisar antara 2,5 miliar hingga 20 miliar.
# -- Di Jakarta, rumah dengan spesifikasi serupa dapat memiliki harga mulai dari puluhan hingga ratusan miliar.
#
# Dengan demikian, RPPI dapat mempertimbangkan untuk berinvestasi pada rumah-rumah dengan karakteristik di atas, mengingat potensi harga yang sangat besar. Investasi ini tidak hanya berfokus pada pasar Jabodetabek, tetapi juga dapat diperluas untuk menyasar kalangan masyarakat atas di luar wilayah tersebut.
